# %% [markdown]
# <a href="https://colab.research.google.com/github/cjerez833/PROGCOM-A/blob/main/CQ3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![343434343434.png](data:image/png;base64,...)

# %% [markdown]
# ![dfdfdfdfdf.png](data:image/png;base64,...)
