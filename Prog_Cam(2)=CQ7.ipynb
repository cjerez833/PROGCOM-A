# %% [markdown]
# <a href="https://colab.research.google.com/github/aduran162/PROGCOM-A/blob/main/Prog_Cam(2)%3DCQ7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#REPOSITORIO DE PALABRAS RESERVADAS EN PYTHON
#Definiciones + ejemplos básicos

palabras_reservadas = {
    "False": "Valor falso",
    "True": "Valor verdadero",
    "None": "Representa la ausencia de valor",
    "and": "Operador lógico AND",
    "or": "Operador lógico OR",
    "not": "Operador lógico de negación",
    "if": "Condicional",
    "elif": "Condicional alternativo",
    "else": "Condicional por defecto",
    "for": "Bucle para iterar",
    "while": "Bucle mientras se cumpla condición",
    "break": "Rompe un ciclo",
    "continue": "Salta a la siguiente iteración",
    "class": "Define una clase",
    "def": "Define una función",
    "return": "Devuelve un valor de una función",
    "import": "Importa un módulo",
    "from": "Importa parte de un módulo",
    "as": "Renombra un módulo o variable",
    "try": "Manejo de excepciones",
    "except": "Captura errores",
    "finally": "Bloque que siempre se ejecuta",
    "raise": "Lanza una excepción",
    "with": "Manejo de contexto (archivos, etc.)",
    "lambda": "Crea funciones anónimas",
    "global": "Declara variables globales",
    "nonlocal": "Declara variables no locales",
    "pass": "No hace nada (placeholder)",
    "yield": "Devuelve un generador"
}

# Mostramos cada palabra con ejemplo simple
for palabra, definicion in palabras_reservadas.items():
    print(f"{palabra}: {definicion}")

# Ejemplo de uso de algunas
print("\n--- EJEMPLOS ---")

# if / else
x = 5
if x > 3:
    print("x es mayor que 3")
else:
    print("x es menor o igual a 3")

# for
for i in range(3):
    print("Iteración:", i)

# función con return
def suma(a, b):
    return a + b

print("Suma:", suma(2, 3))

# lambda
doble = lambda n: n * 2
print("Doble de 4:", doble(4))



#REPOSITORIO DE ERRORES COMUNES


print("\n=== ERRORES COMUNES EN PYTHON ===")

# 1. KeyError
try:
    d = {"a": 1, "b": 2}
    print(d["c"])  # Error porque "c" no existe
except KeyError as e:
    print("KeyError:", e)

# Solución → usar get()
print("Con get():", d.get("c", "No existe"))

# 2. ZeroDivisionError
try:
    print(10/0)
except ZeroDivisionError as e:
    print("ZeroDivisionError:", e)

# Solución → verificar divisor
divisor = 0
if divisor != 0:
    print(10/divisor)
else:
    print("No se puede dividir entre 0")

# 3. NameError
try:
    print(variable_no_definida)
except NameError as e:
    print("NameError:", e)

# Solución → definir antes de usar
variable_no_definida = "Ahora sí existe"
print(variable_no_definida)
# Out:
# False: Valor falso
# True: Valor verdadero
# None: Representa la ausencia de valor
# and: Operador lógico AND
# or: Operador lógico OR
# not: Operador lógico de negación
# if: Condicional
# elif: Condicional alternativo
# else: Condicional por defecto
# for: Bucle para iterar
# while: Bucle mientras se cumpla condición
# break: Rompe un ciclo
# continue: Salta a la siguiente iteración
# class: Define una clase
# def: Define una función
# return: Devuelve un valor de una función
# import: Importa un módulo
# from: Importa parte de un módulo
# as: Renombra un módulo o variable
# try: Manejo de excepciones
# except: Captura errores
# finally: Bloque que siempre se ejecuta
# raise: Lanza una excepción
# with: Manejo de contexto (archivos, etc.)
# lambda: Crea funciones anónimas
# global: Declara variables globales
# nonlocal: Declara variables no locales
# pass: No hace nada (placeholder)
# yield: Devuelve un generador
#
# --- EJEMPLOS ---
# x es mayor que 3
# Iteración: 0
# ...
