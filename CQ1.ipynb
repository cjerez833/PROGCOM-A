# %% [markdown]
# <a href="https://colab.research.google.com/github/cjerez833/PROGCOM-A/blob/main/CQ1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tutun.png](data:image/png;base64,...)

# %% [markdown]
# ![ttatatatatata.png](data:image/png;base64,...)
